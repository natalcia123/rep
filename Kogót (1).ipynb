# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np


zdj= np.array(io.imread('https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Kogut1.JPG/1280px-Kogut1.JPG'))

plt.imshow(zdj)
plt.show()

plt.imshow(zdj[::-1])
plt.show()

plt.imshow(zdj[:,::-1])
plt.show()

plt.imshow(zdj[200:400,300:500])
plt.show()

plt.imshow(zdj+100)
plt.show()

# mask=zdj[:,:,0] <200
# zdj[mask]=255
# plt.imshow(zdj)
# plt.show()
